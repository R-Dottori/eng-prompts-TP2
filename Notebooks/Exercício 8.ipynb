# %% [markdown]
# ## **Exercício 8: Identificação de Entidades em Notícias com LLM**
#
# *Uma consultoria lhe contratou para automatizar a descoberta de pessoas mencionadas em notícias de jornal.*
#
# *Com base no Exercício 7, escolha 3 notícias e monte uma aplicação com um prompt para o LLM identificar menções a diferentes entidades em cada notícia (como pessoas, órgãos públicos, empresas…).*
#
# *Implemente um notebook para testar o código usando a API do Gemini. Descreva o prompt, seus resultados e avalie se a resposta do modelo atende às expectativas da consultoria.*

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

load_dotenv('../.env')

genai.configure(api_key=os.environ['GEMINI_KEY'])

modelo = genai.GenerativeModel('gemini-1.5-flash')

# %%
lista_noticias = [
'https://www.tecmundo.com.br/voxel/294816-gta-6-rodara-problemas-xbox-series-s-sugere-dona-rockstar.htm',
'https://www.tecmundo.com.br/mercado/400023-nvidia-supera-apple-e-e-a-empresa-mais-valiosa-do-mundo.htm',
'https://www.tecmundo.com.br/voxel/294786-sega-removera-jogos-classicos-mega-drive-steam-outras-plataformas-veja-lista-afetados.htm'
]

# %%
import requests
from bs4 import BeautifulSoup as bs

texto_noticias = []

for noticia in lista_noticias:
    resp = requests.get(noticia)
    soup = bs(resp.text)
    texto = soup.select('article > div > div > p')
    texto_noticias.append(texto)

# %%
for contagem, noticia in enumerate(texto_noticias):
    pergunta = f""""
    Identifique na notícia abaixo as principais entidades mencionadas, como pessoas, empresas, objetos discutidos, etc.

    {noticia}
    """

    resposta = modelo.generate_content(pergunta)
    print(f'NOTÍCIA {contagem + 1}: {lista_noticias[contagem]}')
    print(resposta.text)
# Out:
# NOTÍCIA 1: https://www.tecmundo.com.br/voxel/294816-gta-6-rodara-problemas-xbox-series-s-sugere-dona-rockstar.htm
# ## Entidades na notícia:
#
# **Pessoas:**
#
# * **Strauss Zelnick:** CEO da Take-Two
# * **Jogadores:** Público-alvo dos jogos
#
# **Empresas:**
#
# * **Take-Two:** Publisher dona da Rockstar
# * **Rockstar:** Desenvolvedora da franquia GTA
# * **Voxel:** Site de notícias de games (mencionado na chamada para comentários)
#
# **Objetos:**
#
# * **GTA 6:** Jogo em desenvolvimento da Rockstar
# * **Xbox Series S:** Console de videogame da Microsoft
# * **Xbox Series X:** Console de videogame da Microsoft
# * **PS5:** Console de videogame da Sony
# * **PC:** Plataforma de jogos
#
# **Conceitos e Ideias:**
#
# * **Mundo aberto:** Tipo de jogo com grande liberdade de exploração
# * **Hardware:** Equipamentos de computação, como consoles e PCs
# * **Poder de renderização:** Capacidade de um hardware processar gráficos
# * **Experiência de jogo:** Qualidade da experiência do jogador em um jogo
# * **Plataformas:** Ambientes onde os jogos são distribuídos (consoles, PCs, etc.)
#
# **Outros:**
#
# * **Redes sociais:** Meio de comunicação online (mencionado na chamada para comentários)
# * **Teleconferência de resultados financeiros:** Reunião online para discutir performance financeira (mencionada no contexto da declaração de Zelnick)
# * **2025 (entre setembro e dezembro):** Data de lançamento prevista para GTA 6
#
# NOTÍCIA 2: https://www.tecmundo.com.br/mercado/400023-nvidia-supera-apple-e-e-a-empresa-mais-valiosa-do-mundo.htm
# ## Entidades da Notícia:
#
# **Empresas:**
#
# * **Nvidia:** Empresa líder em IA, fabricante de GPUs, desenvolvedora de chips Arm e aceleradores de IA para data centers.
# * **Apple:** Empresa de tecnologia conhecida por seus iPhones, iPads, Macs e softwares, como o iOS e o Apple Intelligence.
# * **Microsoft:** Empresa de tecnologia conhecida por seu sistema operacional Windows, o software Office e o serviço de nuvem Azure.
#
# **Pessoas:**
#
# * **Jensen Huang:** CEO da Nvidia.
# * **Tim Cook:** CEO da Apple.
#
# **Objetos:**
#
# * **Ações:** Títulos que representam a propriedade de uma empresa.
# * **Valor de Mercado:** O valor total de todas as ações de uma empresa.
# * **GPUs:** Unidades de processamento gráfico, componentes de hardware utilizados em jogos e aplicações de IA.
# * **Chips Arm:** Processadores de arquitetura Arm, utilizados em dispositivos móveis e outros dispositivos.
# * **Aceleradores de IA:** Hardware especializado que acelera o processamento de tarefas de IA.
# * **Data Centers:** Centros de dados que armazenam e processam informações.
# * **Placas de vídeo RTX 50:** Nova geração de placas de vídeo de alta performance da Nvidia.
# * **iPhone:** Smartphone produzido pela Apple.
# * **Apple Intelligence:** Pacote de inteligência artificial da Apple para iPhones.
#
# **Outros:**
#
# * **Mercado de ações:** Sistema de negociação de ações de empresas.
# * **Big techs:** Grandes empresas de tecnologia.
# * **IA:** Inteligência artificial.
#
# **Conceitos:**
#
# * **Valorização das ações:** Aumento do preço das ações de uma empresa.
# * **Crescimento da Nvidia:** Expansão da empresa e de seus negócios.
# * **Dinâmica do mercado:** Constantes mudanças no mercado de ações.
# * **Expectativas:** Previsões do mercado sobre o desempenho de uma empresa.
#
# **Informações:**
#
# * **Valor de mercado da Nvidia:** US$ 3,39 trilhões (cerca de R$ 19 trilhões).
# * **Valor de mercado da Apple:** US$ 3,36 trilhões.
# * **Valorização das ações da Apple em 2024:** 17%.
# * **Lançamento da geração Blackwell de GPUs:** Há poucos meses.
# * **Previsão de lançamento das placas de vídeo RTX 50:** Primeiro trimestre de 2025.
#
# NOTÍCIA 3: https://www.tecmundo.com.br/voxel/294786-sega-removera-jogos-classicos-mega-drive-steam-outras-plataformas-veja-lista-afetados.htm
# ## Entidades na notícia:
#
# **Pessoas:**
#
# * Jogadores
#
# **Empresas:**
#
# * SEGA
# * Steam
# * PS Store
# * Microsoft Store
# * Nintendo
# * Nintendo Switch Online
# * Voxel
#
# **Objetos:**
#
# * Jogos clássicos da SEGA
# * Pacotes de jogos
# * Lojas digitais
# * Bibliotecas digitais
# * Plataformas digitais
# * Conta na plataforma
# * Serviço de assinatura
# * FAQ
# * Site oficial de suporte
# * Redes sociais
#
# **Eventos:**
#
# * Remoção de jogos das lojas digitais
# * Aquisição de jogos
# * Download de jogos
# * Acesso a jogos por meio de assinatura
#
# **Conceitos:**
#
# * Clássicos
# * Coleção de jogos
# * Assinatura
# * Suporte
# * Acesso
# * Lista completa
#
# **Outros:**
#
# *  Dia 6 de dezembro de 2024
# *  Mais de 60 jogos
# *  Um mês
# *  Links para sites
# *  Imagens e legendas
# *  Textos em negrito
# *  Títulos de seções
# *  Links para redes sociais

# %% [markdown]
# • **Avaliação da Resposta**
#
# Nesse exercício, utilizei estruturas de repeteição e técnicas de raspagem de dados para extrair o texto de três notícias diferentes. É possível que artefatos da raspagem (como elementos de HTML) tenham afetado a resposta do modelo.
#
# Dito isso, a listagem de empresas e pessoas funcionou como o esperado, destacando e explicando as principais entidades da notícia.
#
# Para além disso, o modelo extrapolou um pouco no que seria considerado relevante, perdendo a consistência no resumo e incluindo conceitos e temas mais vagos, mesmo que estes estivessem presentes na notícia.
#
# Idealmente, o *prompt* deveria ser refeito e restringido somente a empresas e pessoas físicas para atender às expectativas da consultoria.
#
# ---
